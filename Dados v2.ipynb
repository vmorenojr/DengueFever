# %% [markdown]
# # Preparação de dados

# %% [markdown]
# ## Importação de módulos

# %%
! pip install -U vega
# Out:
# Requirement already up-to-date: vega in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (2.4.0)

# %%
! pip install -U vega_datasets
# Out:
# Requirement already up-to-date: vega_datasets in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (0.7.0)
# Requirement already satisfied, skipping upgrade: pandas in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from vega_datasets) (0.23.4)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas->vega_datasets) (2018.7)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas->vega_datasets) (2.8.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas->vega_datasets) (1.16.2)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas->vega_datasets) (1.11.0)

# %%
import datetime as dt
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import altair as alt
alt.renderers.enable('notebook')

from vega_datasets import data

#import seaborn as sns
#sns.set_context("talk")
#sns.set_style("white")

#from IPython.display import HTML
#import urllib
#import bs4 #this is beautiful soup
#import re # regular expressions

# %% [markdown]
# ## Leitura dos dados

# %%
dados = pd.read_csv('dengue_capitais.csv.gz')

# %%
dados.head()
# Out:
#         dt_notificacao co_cid  co_municipio_notificacao  \
# 0  2012-12-27 00:00:00    A90                    110020
# 1  2013-01-14 00:00:00    A90                    110020
# 2  2013-02-12 00:00:00    A90                    500270
# 3  2013-02-08 00:00:00    A90                    520870
# 4  2013-02-27 00:00:00    A90                    431490
#
#    co_municipio_residencia dt_diagnostico_sintoma         dt_digitacao
# 0                   110020    2012-12-21 00:00:00  2013-02-22 00:00:00
# 1                   110020    2013-01-01 00:00:00  2013-02-22 00:00:00
# 2                   500270    2013-02-09 00:00:00  2013-02-23 00:00:00
# 3                   520870    2013-02-01 00:00:00  2013-03-01 00:00:00
# 4                   431490    2013-02-26 00:00:00  2013-02-27 00:00:00

# %%
dados.dtypes
# Out:
# dt_notificacao              object
# co_cid                      object
# co_municipio_notificacao     int64
# co_municipio_residencia      int64
# dt_diagnostico_sintoma      object
# dt_digitacao                object
# dtype: object

# %%
dados.isnull().sum()
# Out:
# dt_notificacao                 0
# co_cid                         0
# co_municipio_notificacao       0
# co_municipio_residencia        0
# dt_diagnostico_sintoma         8
# dt_digitacao                8335
# dtype: int64

# %% [markdown]
# Temos valores omitidos nas colunas dt_diagnostico_sintoma e dt_digitacao. Vamos usar a data da notificação como índice em nossas análises, dado que, de acordo com o especialista consultado, é mais confiável e não tem valores omitidos.

# %% [markdown]
# É necessário transformar as colunas dt_notificacao, dt_diagnostico_sintoma, e dt_digitacao em data (tipo datetime).

# %%
dados.dt_notificacao = pd.to_datetime(dados.dt_notificacao, format = '%Y-%m-%d %H:%M:%S')
dados.dt_diagnostico_sintoma = pd.to_datetime(dados.dt_diagnostico_sintoma, format = '%Y-%m-%d %H:%M:%S')
dados.dt_digitacao = pd.to_datetime(dados.dt_digitacao, format = '%Y-%m-%d %H:%M:%S')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3684688 entries, 0 to 3684687
# Data columns (total 6 columns):
# dt_notificacao              datetime64[ns]
# co_cid                      object
# co_municipio_notificacao    int64
# co_municipio_residencia     int64
# dt_diagnostico_sintoma      datetime64[ns]
# dt_digitacao                datetime64[ns]
# dtypes: datetime64[ns](3), int64(2), object(1)
# memory usage: 168.7+ MB

# %%
dados.isnull().sum()
# Out:
# dt_notificacao                 0
# co_cid                         0
# co_municipio_notificacao       0
# co_municipio_residencia        0
# dt_diagnostico_sintoma         8
# dt_digitacao                8335
# dtype: int64

# %%
dados.head()
# Out:
#   dt_notificacao co_cid  co_municipio_notificacao  co_municipio_residencia  \
# 0     2012-12-27    A90                    110020                   110020
# 1     2013-01-14    A90                    110020                   110020
# 2     2013-02-12    A90                    500270                   500270
# 3     2013-02-08    A90                    520870                   520870
# 4     2013-02-27    A90                    431490                   431490
#
#   dt_diagnostico_sintoma dt_digitacao
# 0             2012-12-21   2013-02-22
# 1             2013-01-01   2013-02-22
# 2             2013-02-09   2013-02-23
# 3             2013-02-01   2013-03-01
# 4             2013-02-26   2013-02-27

# %% [markdown]
# Vamos obter o ano, o mês e a semana de cada data de notificação para uso posterior.

# %%
ano_notificacao = dados.dt_notificacao.dt.year
mes_notificacao = dados.dt_notificacao.dt.month
semana_notificacao = dados.dt_notificacao.dt.week

# %% [markdown]
# Criamos então um novo data_frame apenas com a data da notificacao e o município de residencia.

# %%
dengue = {'data': dados.dt_notificacao,
          'residencia': dados.co_municipio_residencia}

# %%
dengue = pd.DataFrame(dengue)
dengue.head()
# Out:
#         data  residencia
# 0 2012-12-27      110020
# 1 2013-01-14      110020
# 2 2013-02-12      500270
# 3 2013-02-08      520870
# 4 2013-02-27      431490

# %%
dengue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3684688 entries, 0 to 3684687
# Data columns (total 2 columns):
# data          datetime64[ns]
# residencia    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 56.2 MB

# %%
dengue_semana = dengue.groupby(['residencia']).resample('W', on='data').count()

# %%
dengue_semana.head()
# Out:
#                        data  residencia
# residencia data
# 110020     2007-01-07     4           4
#            2007-01-14     9           9
#            2007-01-21    16          16
#            2007-01-28     9           9
#            2007-02-04    11          11

# %%
dengue_semana.drop(columns=['residencia'], inplace=True)
dengue_semana.rename({'data':'ocorrencias'}, axis='columns', inplace=True)

# %%
dengue_semana.head()
# Out:
#                        ocorrencias
# residencia data
# 110020     2007-01-07            4
#            2007-01-14            9
#            2007-01-21           16
#            2007-01-28            9
#            2007-02-04           11

# %%
dengue_semana.index.get_level_values('residencia')
# Out:
# Int64Index([110020, 110020, 110020, 110020, 110020, 110020, 110020, 110020,
#             110020, 110020,
#             ...
#             530010, 530010, 530010, 530010, 530010, 530010, 530010, 530010,
#             530010, 530010],
#            dtype='int64', name='residencia', length=29403)

# %%
dengue_semana.index.get_level_values('data')
# Out:
# DatetimeIndex(['2007-01-07', '2007-01-14', '2007-01-21', '2007-01-28',
#                '2007-02-04', '2007-02-11', '2007-02-18', '2007-02-25',
#                '2007-03-04', '2007-03-11',
#                ...
#                '2019-03-10', '2019-03-17', '2019-03-24', '2019-03-31',
#                '2019-04-07', '2019-04-14', '2019-04-21', '2019-04-28',
#                '2019-05-05', '2019-05-12'],
#               dtype='datetime64[ns]', name='data', length=29403, freq=None)

# %% [markdown]
# ### Plot da série para um município

# %%
dengue_semana.loc[110020].plot(figsize=(20,10), linewidth=3, fontsize=15)
plt.xlabel('Ano', fontsize=20)
# Out:
# Text(0.5, 0, 'Ano')

# %% [markdown]
# ### Plot das séries de todos os municípios de residência

# %%
dados_alt = dengue_semana.reset_index()
dados_alt.head()
# Out:
#    residencia       data  ocorrencias
# 0      110020 2007-01-07            4
# 1      110020 2007-01-14            9
# 2      110020 2007-01-21           16
# 3      110020 2007-01-28            9
# 4      110020 2007-02-04           11

# %% [markdown]
# ### Problema
# A base é grande e o Altair tem um limite de 5000 observações. Não consegui fazer funcionar usando as informações do link https://altair-viz.github.io/user_guide/faq.html?highlight=large%20dataset#maxrowserror-how-can-i-plot-large-datasets

# %%
dados_alt = dados_alt[dados_alt.residencia.isin([110020, 120040, 130260])]
dados_alt.residencia.unique()
# Out:
# array([110020, 120040, 130260])

# %%
alt.Chart(dados_alt).mark_line().encode(
    x='data',
    y='ocorrencias',
    color = 'residencia:N'
)

# %%
highlight = alt.selection(type='single', 
                          on='mouseover',
                          fields=['residencia'],
                          nearest=True)

base = alt.Chart(dados_alt).encode(
    x='data:T',
    y='ocorrencias:Q',
    color='residencia:N'
)

points = base.mark_circle().encode(
    opacity=alt.value(0)
).add_selection(
    highlight
).properties(
    width=600
)

linhas = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(1), alt.value(3))
).interactive()

points + linhas

# %% [markdown]
# ### Lista de municípios da notificação e de residência da pessoa que contraiu dengue.

# %%
municipios = sorted(dados.co_municipio_notificacao.unique().tolist())
residencias = sorted(dados.co_municipio_residencia.unique().tolist())

print(type(municipios), len(municipios), type(residencias), len(residencias))
# Out:
# <class 'list'> 2055 <class 'list'> 28

# %% [markdown]
# ### Problema:
# Temos 2055 municípios de notificação e apenas 28 de residência

# %%
residencias
# Out:
# [110020,
#  120040,
#  130260,
#  140010,
#  150140,
#  160030,
#  172100,
#  211130,
#  221100,
#  230440,
#  240810,
#  250750,
#  261160,
#  270430,
#  280030,
#  292740,
#  310620,
#  320530,
#  330455,
#  355030,
#  410690,
#  410830,
#  420540,
#  431490,
#  500270,
#  510340,
#  520870,
#  530010]
